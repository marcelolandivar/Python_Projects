# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelolandivar/Python_Projects/blob/master/Test_Python_Cassandra_%26_Pymongo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Test of NoSQL Databases in Python
#
# - Marcelo Landivar

# %% [markdown]
# **Test Cassandra - Python Connection**
#
# - Access to a Cassandra Cluster
# - Test different queries in Cassandra
# - Print it into a Pandas Dataframe

# %%
import logging
from cassandra.cluster import Cluster
import pandas as pd

# %%
logging.basicConfig(level=logging.INFO)

cluster = Cluster(['127.0.0.1'], port=9042)
session = cluster.connect()
# Out:
# WARNING:cassandra.cluster:Cluster.__init__ called with contact_points specified, but no load_balancing_policy. In the next major version, this will raise an error; please specify a load-balancing policy. (contact_points = ['127.0.0.1'], lbp = None)
# WARNING:cassandra.cluster:Downgrading core protocol version from 66 to 65 for 127.0.0.1:9042. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# WARNING:cassandra.cluster:Downgrading core protocol version from 65 to 4 for 127.0.0.1:9042. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# ...

# %%
session.execute("""
        CREATE KEYSPACE IF NOT EXISTS infrastructure
        WITH REPLICATION =
        { 'class' : 'SimpleStrategy', 'replication_factor' : 1 }
        """)
session.set_keyspace('infrastructure')

# %%
session.execute("""
                CREATE TABLE IF NOT EXISTS Employees (
                unique_id text
                , employee_name text
                , gender text
                , department text
                , salary float
                , PRIMARY KEY (unique_id))
                """)

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('1', 'Jorge', 'Male', 'Data', 5000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('2', 'Alejandra', 'Female', 'Data', 5000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('3', 'Adam', 'Male', 'Business', 5000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('4', 'David', 'Male', 'Data', 5000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('5', 'Taymara', 'Female', 'Research', 5000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('6', 'Kate', 'Female', 'Business', 5000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('7', 'Francisco', 'Male', 'Technology', 8000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('8', 'Giuseppe', 'Male', 'Technology', 8000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('9', 'Alex', 'Male', 'Statistics', 8000)""")

# %%
session.execute("""
                INSERT INTO Employees 
                (unique_id, employee_name, gender, department, salary)
                VALUES ('10', 'Marcel', 'Male', 'Business', 5000)""")

# %%
SELECT = session.execute(""" SELECT * FROM Employees""")

# %%
SELECT._current_rows
# Out:
#   unique_id  department employee_name  gender  salary
# 0         6    Business          Kate  Female  5000.0
# 1         7  Technology     Francisco    Male  8000.0
# 2         9  Statistics          Alex    Male  8000.0
# 3        10    Business        Marcel    Male  5000.0
# 4         4        Data         David    Male  5000.0
# 5         3    Business          Adam    Male  5000.0
# 6         5    Research       Taymara  Female  5000.0
# 7         8  Technology      Giuseppe    Male  8000.0
# 8         2        Data     Alejandra  Female  5000.0
# 9         1        Data         Jorge    Male  5000.0

# %%
def pandas_factory(colnames, rows):
    return pd.DataFrame(rows, columns=colnames)

# %%
session.row_factory = pandas_factory
rows = session.execute("""SELECT * FROM Employees""")

# %%
df = rows._current_rows

# %%
df
# Out:
#   unique_id  department employee_name  gender  salary
# 0         6    Business          Kate  Female  5000.0
# 1         7  Technology     Francisco    Male  8000.0
# 2         9  Statistics          Alex    Male  8000.0
# 3        10    Business        Marcel    Male  5000.0
# 4         4        Data         David    Male  5000.0
# 5         3    Business          Adam    Male  5000.0
# 6         5    Research       Taymara  Female  5000.0
# 7         8  Technology      Giuseppe    Male  8000.0
# 8         2        Data     Alejandra  Female  5000.0
# 9         1        Data         Jorge    Male  5000.0

# %% [markdown]
# ---

# %% [markdown]
# #Test Pymongo
# - Test MongoDB cluster with Pymongo
# - Test queries in Pymongo
# - Print it into a Pandas Dataframe

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
cluster = MongoClient('mongodb+srv://marcelo_landivar_24:GalaxyS3@btscluster-oq18p.mongodb.net/test?retryWrites=true&w=majority')

# %%
db = cluster['sample_training']

# %%
collection = db['companies']

# %%
import pprint

# %%
query={'name':1, 'founder_year':1, 'category_code':1, 'product':1}

# %%
for result in collection.find({}, query):
    pprint.pprint(result)
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#  'category_code': 'web',
#  'name': 'Wetpaint'}
# {'_id': ObjectId('52cdef7c4bab8bd675297d8e'),
#  'category_code': 'social',
#  'name': 'Facebook'}
# {'_id': ObjectId('52cdef7c4bab8bd675297d8f'),
#  'category_code': 'network_hosting',
#  'name': 'Omnidrive'}
# {'_id': ObjectId('52cdef7c4bab8bd675297d94'),
#  'category_code': 'social',
#  'name': 'Twitter'}
# {'_id': ObjectId('52cdef7c4bab8bd675297d95'),
#  'category_code': 'web',
#  'name': 'StumbleUpon'}
# {'_id': ObjectId('52cdef7c4bab8bd675297d97'),
#  'category_code': 'news',
#  'name': 'Scribd'}
# {'_id': ObjectId('52cdef7c4bab8bd675297d98'),
#  'category_code': 'music',
#  'name': 'Slacker'}
# {'_id': ObjectId('52cdef7c4bab8bd675297d9e'),
#  'category_code': 'news',
#  'name': 'CBS'}
# {'_id': ObjectId('52cdef7c4bab8bd675297da0'),
#  'category_code': 'games_video',
#  'name': 'Babelgum'}
# {'_id': ObjectId('52cdef7c4bab8bd675297da1'),
#  'category_code': 'web',
# ...

# %%
pprint.pprint(collection.find_one({"name": "Omnidrive"}))
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297d8f'),
#  'acquisition': None,
#  'acquisitions': [],
#  'alias_list': None,
#  'blog_feed_url': 'http://feeds.feedburner.com/omnidrive',
#  'blog_url': 'http://www.omnidrive.com/blog',
#  'category_code': 'network_hosting',
#  'competitions': [{'competitor': {'name': 'Dropbox', 'permalink': 'dropbox'}},
#                   {'competitor': {'name': 'filobite', 'permalink': 'filobite'}},
#                   {'competitor': {'name': 'digitalbucket.net',
#                                   'permalink': 'digitalbucket'}},
#                   {'competitor': {'name': 'ElephantDrive',
#                                   'permalink': 'elephantdrive'}},
#                   {'competitor': {'name': 'Banckle Customer Service 2.0',
#                                   'permalink': 'banckle'}}],
#  'created_at': 'Sun May 27 03:25:32 UTC 2007',
#  'crunchbase_url': 'http://www.crunchbase.com/company/omnidrive',
#  'deadpooled_day': 15,
#  'deadpooled_month': 9,
# ...

# %%
query2 = {'founded_year':{'$gt':2005}, 'category_code':'social'}

# %%
df = pd.DataFrame(list(collection.find(query2)))
